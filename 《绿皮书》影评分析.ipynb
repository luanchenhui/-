# %%
import requests
from bs4 import BeautifulSoup

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

print('库导入成功')
# Out:
# 库导入成功

# %%
# 网页数据采集测试
u1 = 'https://movie.douban.com/subject/27060077/comments?status=P'
# u = 'https://movie.douban.com/subject/26100958/comments?start=0&limit=20&sort=new_score&status=P'
r = requests.get(url=u1)
r.encoding = 'utf-8'
# 访问网页
soup = BeautifulSoup(r.text)
# 解析网页
infor_lst = soup.find('div',id="comments").find_all('div',class_="comment-item")
len(infor_lst)
# Out:
# 20

# %%
# 将网页内的信息按照感兴趣目标进行提取整理
dic = {}
for infor in infor_lst[:]:
    dic['评论者'] = infor.find('span',class_="comment-info").find('a').text
    dic['评分'] = int(infor.find('span',class_="comment-info").find_all('span')[1]['class'][0][-2:])
    dic['评论时间'] = infor.find('span',class_="comment-time").text.replace(' ','').replace('\n','')
    dic['有用数量'] = int(infor.find('span',class_="votes").text)
    dic['评论内容'] = infor.find('p').text.replace('\n','')

print(dic)
# Out:
# {'评论者': 'JoshuaLi', '评分': 50, '评论时间': '2018-12-04', '有用数量': 115, '评论内容': 'Viggo Mortensen对Tony这个角色的诠释是极为讨喜的幽默风趣、粗俗却带有真情实感的意大利裔工人阶级形象，而Mahershala Ali对Don Shirley这个角色的诠释是谨慎悲观却又优雅文明受过高等教育与天赋异常的非裔艺术家形象，两个截然不同的角色在一段旅途中在种族以及价值观的冲突中取得相互谅解并建立起互助的朋友关系，而两个角色身份的反差在深南部的州这样的设定里得到了更加微妙与具有对比性的挖掘，这部有着优秀表演的公路电影有着中规中矩的叙事与摄影，但影片在一个没有野心的层面对这个题材的诠释已经足够优秀，这是一部有着良好用心没有过度剥削题材价值的暖人心肠的公路电影。'}

# %%
# 构建网页信息获取函数
def get_data(urli):
    try:
        ri = requests.get(url = urli)
        ri.encoding = 'utf-8'
            # 访问网页
        soupi = BeautifulSoup(ri.text)
            # 解析网页
        infor_lst = soupi.find('div',id="comments").find_all('div',class_="comment-item")
            # 获取所有招聘标签div
        datalsti = []
        for infor in infor_lst[:]:
            dic = {}
            dic['评论者'] = infor.find('span',class_="comment-info").find('a').text
            dic['评分'] = int(infor.find('span',class_="comment-info").find_all('span')[1]['class'][0][-2:])
            dic['评论时间'] = infor.find('span',class_="comment-time").text.replace(' ','').replace('\n','')
            dic['有用数量'] = int(infor.find('span',class_="votes").text)
            dic['评论内容'] = infor.find('p').text.replace('\n','')
            datalsti.append(dic)
        return datalsti
    except:
        return []

# u = 'https://movie.douban.com/subject/26100958/comments?start=0&limit=20&sort=new_score&status=P'
u1 = 'https://movie.douban.com/subject/27060077/comments?status=P'
get_data(u1)[:3]
# Out:
# [{'评论者': '陈大希',
#   '评分': 50,
#   '评论时间': '2019-01-13',
#   '有用数量': 12907,
#   '评论内容': '让人印象最深的片段是他们的车在南部的乡间小路上抛锚，和田里劳作的黑奴对视的那一幕，无声却发出巨响。'},
#  {'评论者': '王大根',
#   '评分': 40,
#   '评论时间': '2019-03-01',
#   '有用数量': 7903,
#   '评论内容': '肯德基年度推广大电影'},
#  {'评论者': 'Rocrw',
#   '评分': 50,
#   '评论时间': '2018-09-12',
#   '有用数量': 5202,
#   '评论内容': '绝对是今年tiff我看过的最有意思的一部电影，全场笑声掌声就没停过。节奏欢快，情节有趣又不失深度。V叔扮演的来自Bronx街头的意大利裔司机和Ali扮演的受高等教育的黑人音乐家碰撞出令人惊喜的火花，二人从纽约一路向南巡演，然而越向南种族歧视也越来越严重。导演用一种巧妙的角度向观众展示了当时的不公以及音乐家内心的纠葛。尽管他从小就在不同的重要场合表演，然而最尽兴的一次却是在圣诞前夕的一个黑人小酒吧。他最终选择了为自己发声，不再对歧视屈服。结局温馨感人，着实是一部好电影。'}]

# %%
# 构建网页信息获取函数
# u = 'https://movie.douban.com/subject/26100958/comments?start=0&limit=20&sort=new_score&status=P'
u1 = 'https://movie.douban.com/subject/27060077/comments?status=P'
get_data(u1)[:2]
# Out:
# [{'评论者': '陈大希',
#   '评分': 50,
#   '评论时间': '2019-01-13',
#   '有用数量': 12907,
#   '评论内容': '让人印象最深的片段是他们的车在南部的乡间小路上抛锚，和田里劳作的黑奴对视的那一幕，无声却发出巨响。'},
#  {'评论者': '王大根',
#   '评分': 40,
#   '评论时间': '2019-03-01',
#   '有用数量': 7903,
#   '评论内容': '肯德基年度推广大电影'}]

# %%
# 构建获取页面url函数
def get_urls(n):
    urllst = []
    for i in range(n):
        # urllst.append('https://movie.douban.com/subject/26100958/comments?start=%i&limit=20&sort=new_score&status=P' % (i*20))
        urllst.append('https://movie.douban.com/subject/27060077/comments?start=%i&limit=20&sort=new_score&status=P' % (i*20))
    return urllst

urllsts = get_urls(50)
urllsts[:2]
# Out:
# ['https://movie.douban.com/subject/27060077/comments?start=0&limit=20&sort=new_score&status=P',
#  'https://movie.douban.com/subject/27060077/comments?start=20&limit=20&sort=new_score&status=P']

# %%
# 批量获取数据

datalst = []
n = 1
for u in urllsts:
    datalst.extend(get_data(u))
    print('成功获取%i条数据' % (n*20))
    n += 1

datalst[:2]
# Out:
# 成功获取20条数据
# 成功获取40条数据
# 成功获取60条数据
# 成功获取80条数据
# 成功获取100条数据
# 成功获取120条数据
# 成功获取140条数据
# 成功获取160条数据
# 成功获取180条数据
# 成功获取200条数据
# 成功获取220条数据
# 成功获取240条数据
# 成功获取260条数据
# 成功获取280条数据
# 成功获取300条数据
# 成功获取320条数据
# 成功获取340条数据
# 成功获取360条数据
# 成功获取380条数据
# 成功获取400条数据
# 成功获取420条数据
# 成功获取440条数据
# 成功获取460条数据
# 成功获取480条数据
# 成功获取500条数据
# 成功获取520条数据
# 成功获取540条数据
# 成功获取560条数据
# 成功获取580条数据
# 成功获取600条数据
# 成功获取620条数据
# 成功获取640条数据
# 成功获取660条数据
# 成功获取680条数据
# 成功获取700条数据
# 成功获取720条数据
# 成功获取740条数据
# 成功获取760条数据
# 成功获取780条数据
# 成功获取800条数据
# 成功获取820条数据
# 成功获取840条数据
# 成功获取860条数据
# 成功获取880条数据
# 成功获取900条数据
# 成功获取920条数据
# 成功获取940条数据
# 成功获取960条数据
# 成功获取980条数据
# 成功获取1000条数据
# [{'评论者': '陈大希',
#   '评分': 50,
#   '评论时间': '2019-01-13',
#   '有用数量': 12907,
#   '评论内容': '让人印象最深的片段是他们的车在南部的乡间小路上抛锚，和田里劳作的黑奴对视的那一幕，无声却发出巨响。'},
#  {'评论者': '王大根',
#   '评分': 40,
#   '评论时间': '2019-03-01',
#   '有用数量': 7903,
#   '评论内容': '肯德基年度推广大电影'}]

# %%
# 数据格式转换

df = pd.DataFrame(datalst)
df.iloc[:10]
# Out:
#     有用数量  评分                                               评论内容        评论时间  \
# 0  12907  50  让人印象最深的片段是他们的车在南部的乡间小路上抛锚，和田里劳作的黑奴对视的那一幕，无声却发出巨响。  2019-01-13
# 1   7903  40                                         肯德基年度推广大电影  2019-03-01
# 2   5202  50  绝对是今年tiff我看过的最有意思的一部电影，全场笑声掌声就没停过。节奏欢快，情节有趣又不失...  2018-09-12
# 3   3752  50  Mahershala說片子里某個根本不會被人注意到的佈景里的某塊石頭或許就是V撿的。他說V在...  2018-09-12
# 4   3703  50  今年看过最好的剧情片之一。剧本扎实，细节充实，表演到位。颇有《为黛西小姐开车》和《触不可及》...  2018-09-14
# 5   3751  50  肤色对调版《触不可及》，一场跨越美国的公路之旅，更是一场跨越种族与肤色、身份与阶层的人性之旅...  2019-01-17
# 6   2996  50  你知道这个故事要讲什么，你也知道这段旅程会经历什么。你明白这其中并不会触及什么过于深刻的东西...  2018-12-09
# 7   4612  40  肤色、阶层、性格和性取向天差地远的两个男人，因为音乐而结缘，因为公路旅行而成为一生朋友。有时...  2018-12-07
# 8   2540  50  基层白人司机护送著名黑人钢琴家在美国南部巡回演出的故事。两位角色的社会阶级和教育程度的差异，...  2018-09-13
# 9   2387  40  “世界上孤独的人都害怕迈出第一步” 可爱精致的友情小品，美国版《触不可及》。“爱上你是件毫不...  2019-01-13
#
#               评论者
# 0             陈大希
# 1             王大根
# 2           Rocrw
# 3  StarlightRiver
# 4              饮歌
# 5              凌睿
# 6            技术原因
# 7        同志亦凡人中文站
# 8        larawebb
# 9              影志

# %%
# 评论字数数据分布

df['评论字数'] = df['评论内容'].str.len()

plt.figure(figsize = (12,5))
plt.title('评论字数数据分布')
df['评论字数'].hist(bins = 20,edgecolor = 'white')
plt.grid(linestyle='--')

df.head()
# Out:
#     有用数量  评分                                               评论内容        评论时间  \
# 0  12907  50  让人印象最深的片段是他们的车在南部的乡间小路上抛锚，和田里劳作的黑奴对视的那一幕，无声却发出巨响。  2019-01-13
# 1   7903  40                                         肯德基年度推广大电影  2019-03-01
# 2   5202  50  绝对是今年tiff我看过的最有意思的一部电影，全场笑声掌声就没停过。节奏欢快，情节有趣又不失...  2018-09-12
# 3   3752  50  Mahershala說片子里某個根本不會被人注意到的佈景里的某塊石頭或許就是V撿的。他說V在...  2018-09-12
# 4   3703  50  今年看过最好的剧情片之一。剧本扎实，细节充实，表演到位。颇有《为黛西小姐开车》和《触不可及》...  2018-09-14
#
#               评论者  评论字数
# 0             陈大希    49
# 1             王大根    10
# 2           Rocrw   236
# 3  StarlightRiver   318
# 4              饮歌    81
# <img src="https://cdn.kesci.com/rt_upload/E7A29F0EE19E41E0827FDA727D8E4227/ptsiqytc2h.png">

# %%
# 有用数量数据分布

plt.figure(figsize = (12,5))
plt.title('有用数量数据分布')
df['有用数量'].hist(bins = 50,edgecolor = 'white')
plt.grid(linestyle='--')
# Out:
# <img src="https://cdn.kesci.com/rt_upload/68079E1851F9413EAC20A7DAFEC48902/ptsiqyo6jg.png">

# %%
# 评论字数与有用数量关系

plt.figure(figsize = (12,5))
plt.title('评论字数与有用数量关系')
plt.scatter(df['评论字数'],df['有用数量'],alpha = 0.4)
plt.xlabel('评论字数')
plt.ylabel('有用数量')
plt.grid(linestyle='--')

df[df['有用数量']>5000].sort_values(by = '有用数量',ascending = False)
# Out:
#      有用数量  评分                                               评论内容        评论时间  \
# 0   12907  50  让人印象最深的片段是他们的车在南部的乡间小路上抛锚，和田里劳作的黑奴对视的那一幕，无声却发出巨响。  2019-01-13
# 15  12012  30  “如果我不够黑人，也不够白人，又或不够男人，那请你告诉我，托尼，那我到底算是什么人？！”——...  2019-02-26
# 1    7903  40                                         肯德基年度推广大电影  2019-03-01
# 2    5202  50  绝对是今年tiff我看过的最有意思的一部电影，全场笑声掌声就没停过。节奏欢快，情节有趣又不失...  2018-09-12
#
#       评论者  评论字数
# 0     陈大希    49
# 15    易老邪    59
# 1     王大根    10
# 2   Rocrw   236
# <img src="https://cdn.kesci.com/rt_upload/DB6EE7E167364EA6AAE27CBB92A17D0D/ptsiqzjw9g.png">

# %%
# 评论字数与评分关系

plt.figure(figsize = (12,5))
plt.title('评论字数与评分关系')
plt.scatter(df['评论字数'],df['评分'],alpha = 0.4)
plt.xlabel('评论字数')
plt.ylabel('评分')
plt.grid(linestyle='--')
# Out:
# <img src="https://cdn.kesci.com/rt_upload/1B54668938DC4F6A8E61F5BF73F524D4/ptsiqzk0lx.png">

# %%
# 评论时间与有用数量关系

plt.figure(figsize = (12,5))
plt.title('评论时间与有用数量')
plt.scatter(df['评论时间'],df['有用数量'],alpha = 0.4,color='red')
plt.xlabel('评论时间')
plt.ylabel('有用数量')
plt.grid(linestyle='--')
# Out:
# <img src="https://cdn.kesci.com/rt_upload/81A5ACAF786B487B8B7A37EFDF086EBF/ptsir0arw8.png">

# %%
# 评论时间与评分关系

plt.figure(figsize = (12,5))
plt.title('评论时间与评分关系')
plt.scatter(df['评论时间'],df['评分'],alpha = 0.4,color='red')
plt.xlabel('评论时间')
plt.ylabel('评分')
plt.grid(linestyle='--')
# Out:
# <img src="https://cdn.kesci.com/rt_upload/656DB788376A4D18868708C70BD4477F/ptsir1o9ja.png">

# %%
df.head()
# Out:
#     有用数量  评分                                               评论内容        评论时间  \
# 0  12907  50  让人印象最深的片段是他们的车在南部的乡间小路上抛锚，和田里劳作的黑奴对视的那一幕，无声却发出巨响。  2019-01-13
# 1   7903  40                                         肯德基年度推广大电影  2019-03-01
# 2   5202  50  绝对是今年tiff我看过的最有意思的一部电影，全场笑声掌声就没停过。节奏欢快，情节有趣又不失...  2018-09-12
# 3   3752  50  Mahershala說片子里某個根本不會被人注意到的佈景里的某塊石頭或許就是V撿的。他說V在...  2018-09-12
# 4   3703  50  今年看过最好的剧情片之一。剧本扎实，细节充实，表演到位。颇有《为黛西小姐开车》和《触不可及》...  2018-09-14
#
#               评论者  评论字数
# 0             陈大希    49
# 1             王大根    10
# 2           Rocrw   236
# 3  StarlightRiver   318
# 4              饮歌    81

# %%
keyword = '黑人'
n = 0
for i in df['评论内容']:
    if keyword in i:
        n += 1
print(len(df))
print(n)
# Out:
# 80
# 31

# %%
# 创建函数查找文字出现次数

def name_count(namei,s):
    n = 0
    for i in s:
        if namei in i:
            n += 1
    return n

name_count('黑人',df['评论内容'])
# Out:
# 31

# %%
namelst = ['黑人','南方','乡村','白人','平等','救赎','音乐']
            
for i in namelst:
    print(i,name_count(i,df['评论内容']))
# Out:
# 黑人 31
# 南方 5
# 乡村 0
# 白人 19
# 平等 6
# 救赎 2
# 音乐 12

# %%
# 计算不同关键字出现频率

namelst = ['黑人','南方','乡村','白人','平等','救赎','音乐']

lst = []
for namei in namelst:
    lst.append({'关键词': namei,'出现频率': name_count(namei,df['评论内容'])})

lst
# Out:
# [{'关键词': '黑人', '出现频率': 31},
#  {'关键词': '南方', '出现频率': 5},
#  {'关键词': '乡村', '出现频率': 0},
#  {'关键词': '白人', '出现频率': 19},
#  {'关键词': '平等', '出现频率': 6},
#  {'关键词': '救赎', '出现频率': 2},
#  {'关键词': '音乐', '出现频率': 12}]

# %%
pd.DataFrame(lst)
# Out:
#   关键词  出现频率
# 0  黑人    31
# 1  南方     5
# 2  乡村     0
# 3  白人    19
# 4  平等     6
# 5  救赎     2
# 6  音乐    12

# %%
result = pd.DataFrame(lst)
result.to_csv('/home/kesci/result.csv')

# %%
for i in lst:
    print(i['关键词'],' ',i['出现频率'])
# Out:
# 黑人   31
# 南方   5
# 乡村   0
# 白人   19
# 平等   6
# 救赎   2
# 音乐   12
